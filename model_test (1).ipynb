# %%
# !pip install huggingface_hub
# Out:
# Collecting huggingface_hub
#   Downloading huggingface_hub-1.4.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (2024.6.1)
# Collecting hf-xet<2.0.0,>=1.2.0 (from huggingface_hub)
#   Downloading hf_xet-1.2.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (0.28.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (6.0.3)
# Collecting shellingham (from huggingface_hub)
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting tqdm>=4.42.1 (from huggingface_hub)
#   Downloading tqdm-4.67.3-py3-none-any.whl.metadata (57 kB)
# Collecting typer-slim (from huggingface_hub)
#   Downloading typer_slim-0.21.1-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (4.15.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub) (4.11.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub) (3.10)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface_hub) (0.16.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.12/dist-packages (from anyio->httpx<1,>=0.23.0->huggingface_hub) (1.3.1)
# Collecting click>=8.0.0 (from typer-slim->huggingface_hub)
#   Downloading click-8.3.1-py3-none-any.whl.metadata (2.6 kB)
# Downloading huggingface_hub-1.4.0-py3-none-any.whl (553 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 553.2/553.2 kB 5.1 MB/s  0:00:00
# Downloading hf_xet-1.2.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 37.5 MB/s  0:00:00
# Downloading tqdm-4.67.3-py3-none-any.whl (78 kB)
# Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Downloading typer_slim-0.21.1-py3-none-any.whl (47 kB)
# Downloading click-8.3.1-py3-none-any.whl (108 kB)
# Installing collected packages: tqdm, shellingham, hf-xet, click, typer-slim, huggingface_hub
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6/6 [huggingface_hub] [huggingface_hub]
# Successfully installed click-8.3.1 hf-xet-1.2.0 huggingface_hub-1.4.0 shellingham-1.5.4 tqdm-4.67.3 typer-slim-0.21.1

# %%
from huggingface_hub import notebook_login
notebook_login()
# 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
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
# !git clone https://github.com/Shakker-Labs/RepText
# Out:
# Cloning into 'RepText'...
# remote: Enumerating objects: 52, done.
# remote: Counting objects: 100% (52/52), done.
# remote: Compressing objects: 100% (49/49), done.
# remote: Total 52 (delta 12), reused 2 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (52/52), 57.19 MiB | 3.81 MiB/s, done.
# Resolving deltas: 100% (12/12), done.
# Updating files: 100% (21/21), done.

# %%
import os
os.chdir("RepText")

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 1)) (2.8.0+cu128)
# Collecting transformers (from -r requirements.txt (line 2))
#   Downloading transformers-5.0.0-py3-none-any.whl.metadata (37 kB)
# Collecting accelerate (from -r requirements.txt (line 3))
#   Downloading accelerate-1.12.0-py3-none-any.whl.metadata (19 kB)
# Collecting safetensors (from -r requirements.txt (line 4))
#   Downloading safetensors-0.7.0-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.1 kB)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 5)) (1.4.0)
# Collecting librosa (from -r requirements.txt (line 6))
#   Downloading librosa-0.11.0-py3-none-any.whl.metadata (8.7 kB)
# Collecting soundfile (from -r requirements.txt (line 7))
#   Downloading soundfile-0.13.1-py2.py3-none-manylinux_2_28_x86_64.whl.metadata (16 kB)
# Collecting pydub (from -r requirements.txt (line 8))
#   Downloading pydub-0.25.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting fastapi (from -r requirements.txt (line 9))
#   Downloading fastapi-0.128.1-py3-none-any.whl.metadata (30 kB)
# Collecting uvicorn (from -r requirements.txt (line 10))
#   Downloading uvicorn-0.40.0-py3-none-any.whl.metadata (6.7 kB)
# Collecting firebase-admin (from -r requirements.txt (line 11))
#   Downloading firebase_admin-7.1.0-py3-none-any.whl.metadata (1.7 kB)
# Collecting python-dotenv (from -r requirements.txt (line 12))
#   Downloading python_dotenv-1.2.1-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 13)) (2.32.5)
# Collecting pydantic (from -r requirements.txt (line 14))
#   Downloading pydantic-2.12.5-py3-none-any.whl.metadata (90 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 15)) (2.1.2)
# Collecting pandas (from -r requirements.txt (line 16))
#   Downloading pandas-3.0.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (79 kB)
# Collecting aiosqlite (from -r requirements.txt (line 17))
#   Downloading aiosqlite-0.22.1-py3-none-any.whl.metadata (4.3 kB)
# Collecting opencv-python-headless (from -r requirements.txt (line 18))
#   Downloading opencv_python_headless-4.13.0.90-cp37-abi3-manylinux_2_28_x86_64.whl.metadata (19 kB)
# Collecting google-cloud-storage (from -r requirements.txt (line 19))
#   Downloading google_cloud_storage-3.9.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 1)) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 1)) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 1)) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 1)) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 1)) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 1)) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 1)) (2024.6.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 1)) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 1)) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 1)) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 1)) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 1)) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 1)) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 1)) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 1)) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 1)) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 1)) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 1)) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 1)) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 1)) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 1)) (1.13.1.3)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 1)) (3.4.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers->-r requirements.txt (line 2)) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers->-r requirements.txt (line 2)) (6.0.3)
# Collecting regex!=2019.12.17 (from transformers->-r requirements.txt (line 2))
#   Downloading regex-2026.1.15-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (40 kB)
# Collecting tokenizers<=0.23.0,>=0.22.0 (from transformers->-r requirements.txt (line 2))
#   Downloading tokenizers-0.22.2-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.3 kB)
# Requirement already satisfied: typer-slim in /usr/local/lib/python3.12/dist-packages (from transformers->-r requirements.txt (line 2)) (0.21.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers->-r requirements.txt (line 2)) (4.67.3)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub->-r requirements.txt (line 5)) (1.2.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub->-r requirements.txt (line 5)) (0.28.1)
# Requirement already satisfied: shellingham in /usr/local/lib/python3.12/dist-packages (from huggingface-hub->-r requirements.txt (line 5)) (1.5.4)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub->-r requirements.txt (line 5)) (4.11.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub->-r requirements.txt (line 5)) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub->-r requirements.txt (line 5)) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub->-r requirements.txt (line 5)) (3.10)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub->-r requirements.txt (line 5)) (0.16.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from accelerate->-r requirements.txt (line 3)) (7.1.0)
# Collecting audioread>=2.1.9 (from librosa->-r requirements.txt (line 6))
#   Downloading audioread-3.1.0-py3-none-any.whl.metadata (9.0 kB)
# Collecting numba>=0.51.0 (from librosa->-r requirements.txt (line 6))
#   Downloading numba-0.63.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.9 kB)
# Collecting scipy>=1.6.0 (from librosa->-r requirements.txt (line 6))
#   Downloading scipy-1.17.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (62 kB)
# Collecting scikit-learn>=1.1.0 (from librosa->-r requirements.txt (line 6))
#   Downloading scikit_learn-1.8.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (11 kB)
# Collecting joblib>=1.0 (from librosa->-r requirements.txt (line 6))
#   Downloading joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from librosa->-r requirements.txt (line 6)) (5.2.1)
# Collecting pooch>=1.1 (from librosa->-r requirements.txt (line 6))
#   Downloading pooch-1.9.0-py3-none-any.whl.metadata (10 kB)
# Collecting soxr>=0.3.2 (from librosa->-r requirements.txt (line 6))
#   Downloading soxr-1.0.0-cp312-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.6 kB)
# Collecting lazy_loader>=0.1 (from librosa->-r requirements.txt (line 6))
#   Downloading lazy_loader-0.4-py3-none-any.whl.metadata (7.6 kB)
# Collecting msgpack>=1.0 (from librosa->-r requirements.txt (line 6))
#   Downloading msgpack-1.1.2-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (8.1 kB)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.12/dist-packages (from soundfile->-r requirements.txt (line 7)) (2.0.0)
# Collecting starlette<0.51.0,>=0.40.0 (from fastapi->-r requirements.txt (line 9))
#   Downloading starlette-0.50.0-py3-none-any.whl.metadata (6.3 kB)
# Collecting annotated-doc>=0.0.2 (from fastapi->-r requirements.txt (line 9))
#   Downloading annotated_doc-0.0.4-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.12/dist-packages (from anyio->httpx<1,>=0.23.0->huggingface-hub->-r requirements.txt (line 5)) (1.3.1)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.12/dist-packages (from uvicorn->-r requirements.txt (line 10)) (8.3.1)
# Collecting cachecontrol>=0.14.3 (from firebase-admin->-r requirements.txt (line 11))
#   Downloading cachecontrol-0.14.4-py3-none-any.whl.metadata (3.1 kB)
# Collecting google-api-core<3.0.0dev,>=2.25.1 (from google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin->-r requirements.txt (line 11))
#   Downloading google_api_core-2.29.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting google-cloud-firestore>=2.21.0 (from firebase-admin->-r requirements.txt (line 11))
#   Downloading google_cloud_firestore-2.23.0-py3-none-any.whl.metadata (10 kB)
# Collecting pyjwt>=2.10.1 (from pyjwt[crypto]>=2.10.1->firebase-admin->-r requirements.txt (line 11))
#   Downloading pyjwt-2.11.0-py3-none-any.whl.metadata (4.0 kB)
# Collecting h2<5,>=3 (from httpx[http2]==0.28.1->firebase-admin->-r requirements.txt (line 11))
#   Downloading h2-4.3.0-py3-none-any.whl.metadata (5.1 kB)
# Collecting googleapis-common-protos<2.0.0,>=1.56.2 (from google-api-core<3.0.0dev,>=2.25.1->google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin->-r requirements.txt (line 11))
#   Downloading googleapis_common_protos-1.72.0-py3-none-any.whl.metadata (9.4 kB)
# Collecting protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 (from google-api-core<3.0.0dev,>=2.25.1->google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin->-r requirements.txt (line 11))
#   Downloading protobuf-6.33.5-cp39-abi3-manylinux2014_x86_64.whl.metadata (593 bytes)
# Collecting proto-plus<2.0.0,>=1.22.3 (from google-api-core<3.0.0dev,>=2.25.1->google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin->-r requirements.txt (line 11))
#   Downloading proto_plus-1.27.1-py3-none-any.whl.metadata (2.2 kB)
# Collecting google-auth<3.0.0,>=2.14.1 (from google-api-core<3.0.0dev,>=2.25.1->google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin->-r requirements.txt (line 11))
#   Downloading google_auth-2.48.0-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->-r requirements.txt (line 13)) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->-r requirements.txt (line 13)) (2.5.0)
# Collecting grpcio<2.0.0,>=1.33.2 (from google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin->-r requirements.txt (line 11))
#   Downloading grpcio-1.76.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (3.7 kB)
# Collecting grpcio-status<2.0.0,>=1.33.2 (from google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin->-r requirements.txt (line 11))
#   Downloading grpcio_status-1.76.0-py3-none-any.whl.metadata (1.1 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth<3.0.0,>=2.14.1->google-api-core<3.0.0dev,>=2.25.1->google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin->-r requirements.txt (line 11))
#   Downloading pyasn1_modules-0.4.2-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: cryptography>=38.0.3 in /usr/lib/python3/dist-packages (from google-auth<3.0.0,>=2.14.1->google-api-core<3.0.0dev,>=2.25.1->google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin->-r requirements.txt (line 11)) (41.0.7)
# Collecting rsa<5,>=3.1.4 (from google-auth<3.0.0,>=2.14.1->google-api-core<3.0.0dev,>=2.25.1->google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin->-r requirements.txt (line 11))
#   Downloading rsa-4.9.1-py3-none-any.whl.metadata (5.6 kB)
# Collecting hyperframe<7,>=6.1 (from h2<5,>=3->httpx[http2]==0.28.1->firebase-admin->-r requirements.txt (line 11))
#   Downloading hyperframe-6.1.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting hpack<5,>=4.1 (from h2<5,>=3->httpx[http2]==0.28.1->firebase-admin->-r requirements.txt (line 11))
#   Downloading hpack-4.1.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting pyasn1>=0.1.3 (from rsa<5,>=3.1.4->google-auth<3.0.0,>=2.14.1->google-api-core<3.0.0dev,>=2.25.1->google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin->-r requirements.txt (line 11))
#   Downloading pyasn1-0.6.2-py3-none-any.whl.metadata (8.4 kB)
# Collecting annotated-types>=0.6.0 (from pydantic->-r requirements.txt (line 14))
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.41.5 (from pydantic->-r requirements.txt (line 14))
#   Downloading pydantic_core-2.41.5-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.3 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic->-r requirements.txt (line 14))
#   Downloading typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->-r requirements.txt (line 16)) (2.9.0.post0)
# Collecting google-cloud-core<3.0.0,>=2.4.2 (from google-cloud-storage->-r requirements.txt (line 19))
#   Downloading google_cloud_core-2.5.0-py3-none-any.whl.metadata (3.1 kB)
# Collecting google-resumable-media<3.0.0,>=2.7.2 (from google-cloud-storage->-r requirements.txt (line 19))
#   Downloading google_resumable_media-2.8.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting google-crc32c<2.0.0,>=1.1.3 (from google-cloud-storage->-r requirements.txt (line 19))
#   Downloading google_crc32c-1.8.0-cp312-cp312-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl.metadata (1.7 kB)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0->soundfile->-r requirements.txt (line 7)) (2.23)
# Collecting llvmlite<0.47,>=0.46.0dev0 (from numba>=0.51.0->librosa->-r requirements.txt (line 6))
#   Downloading llvmlite-0.46.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (5.0 kB)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from pooch>=1.1->librosa->-r requirements.txt (line 6)) (4.5.0)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.2->pandas->-r requirements.txt (line 16)) (1.16.0)
# Collecting threadpoolctl>=3.2.0 (from scikit-learn>=1.1.0->librosa->-r requirements.txt (line 6))
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->-r requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->-r requirements.txt (line 1)) (3.0.3)
# Downloading transformers-5.0.0-py3-none-any.whl (10.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 80.0 MB/s  0:00:00
# Downloading tokenizers-0.22.2-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 45.1 MB/s  0:00:00
# Downloading accelerate-1.12.0-py3-none-any.whl (380 kB)
# Downloading safetensors-0.7.0-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (507 kB)
# Downloading librosa-0.11.0-py3-none-any.whl (260 kB)
# Downloading soundfile-0.13.1-py2.py3-none-manylinux_2_28_x86_64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 20.6 MB/s  0:00:00
# Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Downloading fastapi-0.128.1-py3-none-any.whl (103 kB)
# Downloading starlette-0.50.0-py3-none-any.whl (74 kB)
# Downloading uvicorn-0.40.0-py3-none-any.whl (68 kB)
# Downloading firebase_admin-7.1.0-py3-none-any.whl (137 kB)
# Downloading google_api_core-2.29.0-py3-none-any.whl (173 kB)
# Downloading google_auth-2.48.0-py3-none-any.whl (236 kB)
# Downloading googleapis_common_protos-1.72.0-py3-none-any.whl (297 kB)
# Downloading grpcio-1.76.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (6.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 67.7 MB/s  0:00:00
# Downloading grpcio_status-1.76.0-py3-none-any.whl (14 kB)
# Downloading h2-4.3.0-py3-none-any.whl (61 kB)
# Downloading hpack-4.1.0-py3-none-any.whl (34 kB)
# Downloading hyperframe-6.1.0-py3-none-any.whl (13 kB)
# Downloading proto_plus-1.27.1-py3-none-any.whl (50 kB)
# Downloading protobuf-6.33.5-cp39-abi3-manylinux2014_x86_64.whl (323 kB)
# Downloading rsa-4.9.1-py3-none-any.whl (34 kB)
# Downloading python_dotenv-1.2.1-py3-none-any.whl (21 kB)
# Downloading pydantic-2.12.5-py3-none-any.whl (463 kB)
# Downloading pydantic_core-2.41.5-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 25.7 MB/s  0:00:00
# Downloading pandas-3.0.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (10.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 90.4 MB/s  0:00:00
# Downloading aiosqlite-0.22.1-py3-none-any.whl (17 kB)
# Downloading opencv_python_headless-4.13.0.90-cp37-abi3-manylinux_2_28_x86_64.whl (62.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 MB 130.8 MB/s  0:00:00m0:00:0100:01
# Downloading google_cloud_storage-3.9.0-py3-none-any.whl (321 kB)
# Downloading google_cloud_core-2.5.0-py3-none-any.whl (29 kB)
# Downloading google_crc32c-1.8.0-cp312-cp312-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl (33 kB)
# Downloading google_resumable_media-2.8.0-py3-none-any.whl (81 kB)
# Downloading annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading audioread-3.1.0-py3-none-any.whl (23 kB)
# Downloading cachecontrol-0.14.4-py3-none-any.whl (22 kB)
# Downloading msgpack-1.1.2-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (427 kB)
# Downloading google_cloud_firestore-2.23.0-py3-none-any.whl (411 kB)
# Downloading joblib-1.5.3-py3-none-any.whl (309 kB)
# Downloading lazy_loader-0.4-py3-none-any.whl (12 kB)
# Downloading numba-0.63.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 43.9 MB/s  0:00:00
# Downloading llvmlite-0.46.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 143.7 MB/s  0:00:00m0:00:01
# Downloading pooch-1.9.0-py3-none-any.whl (67 kB)
# Downloading pyasn1-0.6.2-py3-none-any.whl (83 kB)
# Downloading pyasn1_modules-0.4.2-py3-none-any.whl (181 kB)
# Downloading pyjwt-2.11.0-py3-none-any.whl (28 kB)
# Downloading regex-2026.1.15-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (803 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 803.6/803.6 kB 7.4 MB/s  0:00:00
# Downloading scikit_learn-1.8.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (8.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 75.8 MB/s  0:00:00
# Downloading scipy-1.17.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (35.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.0/35.0 MB 119.6 MB/s  0:00:00m0:00:01
# Downloading soxr-1.0.0-cp312-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (238 kB)
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Downloading typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Installing collected packages: pydub, uvicorn, typing-inspection, threadpoolctl, soxr, scipy, safetensors, regex, python-dotenv, pyjwt, pydantic-core, pyasn1, protobuf, opencv-python-headless, msgpack, llvmlite, lazy_loader, joblib, hyperframe, hpack, grpcio, google-crc32c, audioread, annotated-types, annotated-doc, aiosqlite, starlette, soundfile, scikit-learn, rsa, pydantic, pyasn1-modules, proto-plus, pooch, pandas, numba, h2, googleapis-common-protos, google-resumable-media, cachecontrol, librosa, grpcio-status, google-auth, fastapi, tokenizers, google-api-core, accelerate, transformers, google-cloud-core, google-cloud-storage, google-cloud-firestore, firebase-admin
#   Attempting uninstall: pyjwtm━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  5/52 [scipy]
#     Found existing installation: PyJWT 2.7.0━━━━━━━━━━━━━━━━━━  5/52 [scipy]
#     Uninstalling PyJWT-2.7.0:━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  5/52 [scipy]
#       Successfully uninstalled PyJWT-2.7.0━━━━━━━━━━━━━━━━━━━━  5/52 [scipy]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52/52 [firebase-admin]se-admin]-cloud-firestore]
# Successfully installed accelerate-1.12.0 aiosqlite-0.22.1 annotated-doc-0.0.4 annotated-types-0.7.0 audioread-3.1.0 cachecontrol-0.14.4 fastapi-0.128.1 firebase-admin-7.1.0 google-api-core-2.29.0 google-auth-2.48.0 google-cloud-core-2.5.0 google-cloud-firestore-2.23.0 google-cloud-storage-3.9.0 google-crc32c-1.8.0 google-resumable-media-2.8.0 googleapis-common-protos-1.72.0 grpcio-1.76.0 grpcio-status-1.76.0 h2-4.3.0 hpack-4.1.0 hyperframe-6.1.0 joblib-1.5.3 lazy_loader-0.4 librosa-0.11.0 llvmlite-0.46.0 msgpack-1.1.2 numba-0.63.1 opencv-python-headless-4.13.0.90 pandas-3.0.0 pooch-1.9.0 proto-plus-1.27.1 protobuf-6.33.5 pyasn1-0.6.2 pyasn1-modules-0.4.2 pydantic-2.12.5 pydantic-core-2.41.5 pydub-0.25.1 pyjwt-2.11.0 python-dotenv-1.2.1 regex-2026.1.15 rsa-4.9.1 safetensors-0.7.0 scikit-learn-1.8.0 scipy-1.17.0 soundfile-0.13.1 soxr-1.0.0 starlette-0.50.0 threadpoolctl-3.6.0 tokenizers-0.22.2 transformers-5.0.0 typing-inspection-0.4.2 uvicorn-0.40.0

# %%
# !pip install diffusers
# Out:
# Collecting diffusers
#   Downloading diffusers-0.36.0-py3-none-any.whl.metadata (20 kB)
# Collecting importlib_metadata (from diffusers)
#   Downloading importlib_metadata-8.7.1-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from diffusers) (3.20.0)
# Requirement already satisfied: httpx<1.0.0 in /usr/local/lib/python3.12/dist-packages (from diffusers) (0.28.1)
# Requirement already satisfied: huggingface-hub<2.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from diffusers) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from diffusers) (2.1.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from diffusers) (2026.1.15)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from diffusers) (2.32.5)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.12/dist-packages (from diffusers) (0.7.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from diffusers) (11.0.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->diffusers) (4.11.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->diffusers) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->diffusers) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->diffusers) (3.10)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0.0->diffusers) (0.16.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.34.0->diffusers) (2024.6.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.34.0->diffusers) (1.2.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.34.0->diffusers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.34.0->diffusers) (6.0.3)
# Requirement already satisfied: shellingham in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.34.0->diffusers) (1.5.4)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.34.0->diffusers) (4.67.3)
# Requirement already satisfied: typer-slim in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.34.0->diffusers) (0.21.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.34.0->diffusers) (4.15.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.12/dist-packages (from anyio->httpx<1.0.0->diffusers) (1.3.1)
# Collecting zipp>=3.20 (from importlib_metadata->diffusers)
#   Downloading zipp-3.23.0-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->diffusers) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->diffusers) (2.5.0)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.12/dist-packages (from typer-slim->huggingface-hub<2.0,>=0.34.0->diffusers) (8.3.1)
# Downloading diffusers-0.36.0-py3-none-any.whl (4.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 60.2 MB/s  0:00:00
# Downloading importlib_metadata-8.7.1-py3-none-any.whl (27 kB)
# Downloading zipp-3.23.0-py3-none-any.whl (10 kB)
# Installing collected packages: zipp, importlib_metadata, diffusers
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [diffusers]/3 [diffusers]
# Successfully installed diffusers-0.36.0 importlib_metadata-8.7.1 zipp-3.23.0

# %%
# !python infer.py
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_validators.py:202: UserWarning: The `local_dir_use_symlinks` argument is deprecated and ignored in `hf_hub_download`. Downloading to a local directory does not use symlinks anymore.
#   warnings.warn(
# config.json: 100%|██████████████████████████████| 649/649 [00:00<00:00, 323kB/s]
# diffusion_pytorch_model.safetensors: 100%|██| 4.28G/4.28G [00:18<00:00, 229MB/s]
# /usr/local/lib/python3.12/dist-packages/diffusers/models/embeddings.py:2617: FutureWarning: `FluxPosEmbed` is deprecated and will be removed in version 1.0.0. Importing and using `FluxPosEmbed` from `diffusers.models.embeddings` is deprecated. Please import it from `diffusers.models.transformers.transformer_flux`.
#   deprecate("FluxPosEmbed", "1.0.0", deprecation_message)
# model_index.json: 100%|████████████████████████| 536/536 [00:00<00:00, 1.84MB/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Downloading (incomplete total...):   0%|  | 550k/9.77G [00:01<2:34:27, 1.05MB/s]
# Downloading (incomplete total...):  67%|██▋ | 22.6G/33.7G [00:42<00:16, 668MB/s]
# Downloading (incomplete total...):  86%|███▍| 29.0G/33.7G [00:50<00:07, 635MB/s]
# Downloading (incomplete total...): 100%|██▉| 33.7G/33.7G [00:56<00:00, 1.03GB/s]
# Fetching 23 files: 100%|████████████████████████| 23/23 [00:56<00:00,  2.44s/it]
# Download complete: 100%|███████████████████| 33.7G/33.7G [00:56<00:00, 1.03GB/s]
# Loading pipeline components...:   0%|                     | 0/7 [00:00<?, ?it/s]
#
# Loading weights:   0%|                                  | 0/196 [00:00<?, ?it/s]
#
# Loading weights:   1%| | 1/196 [00:00<00:00, 3281.93it/s, Materializing param=te
#
# Loading weights:   1%| | 1/196 [00:00<00:00, 1242.76it/s, Materializing param=te
#
# Loading weights:   1%| | 2/196 [00:00<00:00, 992.03it/s, Materializing param=tex
#
# Loading weights:   1%| | 2/196 [00:00<00:00, 897.08it/s, Materializing param=tex
#
# Loading weights:   2%| | 3/196 [00:00<00:00, 569.52it/s, Materializing param=tex
#
# Loading weights:   2%| | 3/196 [00:00<00:00, 544.69it/s, Materializing param=tex
#
# Loading weights:   2%| | 4/196 [00:00<00:00, 681.00it/s, Materializing param=tex
#
# Loading weights:   2%| | 4/196 [00:00<00:00, 659.04it/s, Materializing param=tex
#
# Loading weights:   3%| | 5/196 [00:00<00:00, 774.34it/s, Materializing param=tex
#
# Loading weights:   3%| | 5/196 [00:00<00:00, 751.99it/s, Materializing param=tex
#
# Loading weights:   3%| | 6/196 [00:00<00:00, 774.55it/s, Materializing param=tex
#
# Loading weights:   3%| | 6/196 [00:00<00:00, 757.55it/s, Materializing param=tex
#
# Loading weights:   4%| | 7/196 [00:00<00:00, 848.44it/s, Materializing param=tex
#
# Loading weights:   4%| | 7/196 [00:00<00:00, 830.44it/s, Materializing param=tex
#
# Loading weights:   4%| | 8/196 [00:00<00:00, 911.71it/s, Materializing param=tex
#
# Loading weights:   4%| | 8/196 [00:00<00:00, 892.62it/s, Materializing param=tex
#
# Loading weights:   5%| | 9/196 [00:00<00:00, 969.78it/s, Materializing param=tex
#
# Loading weights:   5%| | 9/196 [00:00<00:00, 950.99it/s, Materializing param=tex
#
# Loading weights:   5%| | 10/196 [00:00<00:00, 1023.15it/s, Materializing param=t
#
# Loading weights:   5%| | 10/196 [00:00<00:00, 999.74it/s, Materializing param=te
#
# Loading weights:   6%| | 11/196 [00:00<00:00, 1065.75it/s, Materializing param=t
#
# Loading weights:   6%| | 11/196 [00:00<00:00, 1046.74it/s, Materializing param=t
#
# Loading weights:   6%| | 12/196 [00:00<00:00, 1109.56it/s, Materializing param=t
#
# Loading weights:   6%| | 12/196 [00:00<00:00, 1089.31it/s, Materializing param=t
#
# Loading weights:   7%| | 13/196 [00:00<00:00, 1143.65it/s, Materializing param=t
#
# Loading weights:   7%| | 13/196 [00:00<00:00, 1125.15it/s, Materializing param=t
#
# Loading weights:   7%| | 14/196 [00:00<00:00, 1180.92it/s, Materializing param=t
#
# Loading weights:   7%| | 14/196 [00:00<00:00, 1162.98it/s, Materializing param=t
#
# Loading weights:   8%| | 15/196 [00:00<00:00, 1205.08it/s, Materializing param=t
#
# Loading weights:   8%| | 15/196 [00:00<00:00, 1187.16it/s, Materializing param=t
#
# Loading weights:   8%| | 16/196 [00:00<00:00, 1236.85it/s, Materializing param=t
#
# Loading weights:   8%| | 16/196 [00:00<00:00, 1219.81it/s, Materializing param=t
#
# Loading weights:   9%| | 17/196 [00:00<00:00, 1262.00it/s, Materializing param=t
#
# Loading weights:   9%| | 17/196 [00:00<00:00, 1230.17it/s, Materializing param=t
#
# Loading weights:   9%| | 18/196 [00:00<00:00, 1275.42it/s, Materializing param=t
#
# Loading weights:   9%| | 18/196 [00:00<00:00, 1246.76it/s, Materializing param=t
#
# Loading weights:  10%| | 19/196 [00:00<00:00, 1186.90it/s, Materializing param=t
#
# Loading weights:  10%| | 19/196 [00:00<00:00, 1124.34it/s, Materializing param=t
#
# Loading weights:  10%| | 20/196 [00:00<00:00, 1151.71it/s, Materializing param=t
#
# Loading weights:  10%| | 20/196 [00:00<00:00, 1140.55it/s, Materializing param=t
#
# Loading weights:  11%| | 21/196 [00:00<00:00, 1172.42it/s, Materializing param=t
#
# Loading weights:  11%| | 21/196 [00:00<00:00, 1160.57it/s, Materializing param=t
#
# Loading weights:  11%| | 22/196 [00:00<00:00, 1173.52it/s, Materializing param=t
#
# Loading weights:  11%| | 22/196 [00:00<00:00, 1163.09it/s, Materializing param=t
#
# Loading weights:  12%| | 23/196 [00:00<00:00, 1193.32it/s, Materializing param=t
#
# Loading weights:  12%| | 23/196 [00:00<00:00, 1147.87it/s, Materializing param=t
#
# Loading weights:  12%| | 24/196 [00:00<00:00, 1173.27it/s, Materializing param=t
#
# Loading weights:  12%| | 24/196 [00:00<00:00, 1163.17it/s, Materializing param=t
#
# Loading weights:  13%|▏| 25/196 [00:00<00:00, 1189.43it/s, Materializing param=t
#
# Loading weights:  13%|▏| 25/196 [00:00<00:00, 1178.60it/s, Materializing param=t
#
# Loading weights:  13%|▏| 26/196 [00:00<00:00, 1203.28it/s, Materializing param=t
#
# Loading weights:  13%|▏| 26/196 [00:00<00:00, 1193.48it/s, Materializing param=t
#
# Loading weights:  14%|▏| 27/196 [00:00<00:00, 1222.59it/s, Materializing param=t
#
# Loading weights:  14%|▏| 27/196 [00:00<00:00, 1194.90it/s, Materializing param=t
#
# Loading weights:  14%|▏| 28/196 [00:00<00:00, 1221.74it/s, Materializing param=t
#
# Loading weights:  14%|▏| 28/196 [00:00<00:00, 1212.75it/s, Materializing param=t
#
# Loading weights:  15%|▏| 29/196 [00:00<00:00, 1232.52it/s, Materializing param=t
#
# Loading weights:  15%|▏| 29/196 [00:00<00:00, 1220.87it/s, Materializing param=t
#
# Loading weights:  15%|▏| 30/196 [00:00<00:00, 1206.70it/s, Materializing param=t
#
# Loading weights:  15%|▏| 30/196 [00:00<00:00, 1196.52it/s, Materializing param=t
#
# Loading weights:  16%|▏| 31/196 [00:00<00:00, 1153.60it/s, Materializing param=t
#
# Loading weights:  16%|▏| 31/196 [00:00<00:00, 1141.82it/s, Materializing param=t
#
# Loading weights:  16%|▏| 32/196 [00:00<00:00, 1135.70it/s, Materializing param=t
#
# Loading weights:  16%|▏| 32/196 [00:00<00:00, 1113.98it/s, Materializing param=t
#
# Loading weights:  17%|▏| 33/196 [00:00<00:00, 1074.54it/s, Materializing param=t
#
# Loading weights:  17%|▏| 33/196 [00:00<00:00, 1068.36it/s, Materializing param=t
#
# Loading weights:  17%|▏| 34/196 [00:00<00:00, 1089.23it/s, Materializing param=t
#
# Loading weights:  17%|▏| 34/196 [00:00<00:00, 1072.77it/s, Materializing param=t
#
# Loading weights:  18%|▏| 35/196 [00:00<00:00, 1050.09it/s, Materializing param=t
#
# Loading weights:  18%|▏| 35/196 [00:00<00:00, 1044.67it/s, Materializing param=t
#
# Loading weights:  18%|▏| 36/196 [00:00<00:00, 1047.17it/s, Materializing param=t
#
# Loading weights:  18%|▏| 36/196 [00:00<00:00, 1037.88it/s, Materializing param=t
#
# Loading weights:  19%|▏| 37/196 [00:00<00:00, 1040.71it/s, Materializing param=t
#
# Loading weights:  19%|▏| 37/196 [00:00<00:00, 1035.61it/s, Materializing param=t
#
# Loading weights:  19%|▏| 38/196 [00:00<00:00, 1048.68it/s, Materializing param=t
#
# Loading weights:  19%|▏| 38/196 [00:00<00:00, 1043.60it/s, Materializing param=t
#
# Loading weights:  20%|▏| 39/196 [00:00<00:00, 1060.27it/s, Materializing param=t
#
# Loading weights:  20%|▏| 39/196 [00:00<00:00, 1051.60it/s, Materializing param=t
#
# Loading weights:  20%|▏| 40/196 [00:00<00:00, 1066.53it/s, Materializing param=t
#
# Loading weights:  20%|▏| 40/196 [00:00<00:00, 1061.63it/s, Materializing param=t
#
# Loading weights:  21%|▏| 41/196 [00:00<00:00, 1076.41it/s, Materializing param=t
#
# Loading weights:  21%|▏| 41/196 [00:00<00:00, 1065.76it/s, Materializing param=t
#
# Loading weights:  21%|▏| 42/196 [00:00<00:00, 1080.21it/s, Materializing param=t
#
# Loading weights:  21%|▏| 42/196 [00:00<00:00, 1075.67it/s, Materializing param=t
#
# Loading weights:  22%|▏| 43/196 [00:00<00:00, 1092.84it/s, Materializing param=t
#
# Loading weights:  22%|▏| 43/196 [00:00<00:00, 1088.19it/s, Materializing param=t
#
# Loading weights:  22%|▏| 44/196 [00:00<00:00, 1103.63it/s, Materializing param=t
#
# Loading weights:  22%|▏| 44/196 [00:00<00:00, 1098.78it/s, Materializing param=t
#
# Loading weights:  23%|▏| 45/196 [00:00<00:00, 1083.17it/s, Materializing param=t
#
# Loading weights:  23%|▏| 45/196 [00:00<00:00, 1077.99it/s, Materializing param=t
#
# Loading weights:  23%|▏| 46/196 [00:00<00:00, 1092.66it/s, Materializing param=t
#
# Loading weights:  23%|▏| 46/196 [00:00<00:00, 1068.80it/s, Materializing param=t
#
# Loading weights:  24%|▏| 47/196 [00:00<00:00, 1065.82it/s, Materializing param=t
#
# Loading weights:  24%|▏| 47/196 [00:00<00:00, 1057.26it/s, Materializing param=t
#
# Loading weights:  24%|▏| 48/196 [00:00<00:00, 1055.03it/s, Materializing param=t
#
# Loading weights:  24%|▏| 48/196 [00:00<00:00, 1051.01it/s, Materializing param=t
#
# Loading weights:  25%|▎| 49/196 [00:00<00:00, 1065.89it/s, Materializing param=t
#
# Loading weights:  25%|▎| 49/196 [00:00<00:00, 1062.00it/s, Materializing param=t
#
# Loading weights:  26%|▎| 50/196 [00:00<00:00, 1036.53it/s, Materializing param=t
#
# Loading weights:  26%|▎| 50/196 [00:00<00:00, 1026.17it/s, Materializing param=t
#
# Loading weights:  26%|▎| 51/196 [00:00<00:00, 1039.75it/s, Materializing param=t
#
# Loading weights:  26%|▎| 51/196 [00:00<00:00, 1034.88it/s, Materializing param=t
#
# Loading weights:  27%|▎| 52/196 [00:00<00:00, 1039.44it/s, Materializing param=t
#
# Loading weights:  27%|▎| 52/196 [00:00<00:00, 1018.76it/s, Materializing param=t
#
# Loading weights:  27%|▎| 53/196 [00:00<00:00, 1028.66it/s, Materializing param=t
#
# Loading weights:  27%|▎| 53/196 [00:00<00:00, 1025.34it/s, Materializing param=t
#
# Loading weights:  28%|▎| 54/196 [00:00<00:00, 1024.50it/s, Materializing param=t
#
# Loading weights:  28%|▎| 54/196 [00:00<00:00, 1021.17it/s, Materializing param=t
#
# Loading weights:  28%|▎| 55/196 [00:00<00:00, 1023.36it/s, Materializing param=t
#
# Loading weights:  28%|▎| 55/196 [00:00<00:00, 1020.10it/s, Materializing param=t
#
# Loading weights:  29%|▎| 56/196 [00:00<00:00, 1032.83it/s, Materializing param=t
#
# Loading weights:  29%|▎| 56/196 [00:00<00:00, 1029.01it/s, Materializing param=t
#
# Loading weights:  29%|▎| 57/196 [00:00<00:00, 1038.55it/s, Materializing param=t
#
# Loading weights:  29%|▎| 57/196 [00:00<00:00, 1035.37it/s, Materializing param=t
#
# Loading weights:  30%|▎| 58/196 [00:00<00:00, 1046.67it/s, Materializing param=t
#
# Loading weights:  30%|▎| 58/196 [00:00<00:00, 1043.28it/s, Materializing param=t
#
# Loading weights:  30%|▎| 59/196 [00:00<00:00, 1043.74it/s, Materializing param=t
#
# Loading weights:  30%|▎| 59/196 [00:00<00:00, 1040.19it/s, Materializing param=t
#
# Loading weights:  31%|▎| 60/196 [00:00<00:00, 1044.23it/s, Materializing param=t
#
# Loading weights:  31%|▎| 60/196 [00:00<00:00, 1009.26it/s, Materializing param=t
#
# Loading weights:  31%|▎| 61/196 [00:00<00:00, 1017.61it/s, Materializing param=t
#
# Loading weights:  31%|▎| 61/196 [00:00<00:00, 1013.95it/s, Materializing param=t
#
# Loading weights:  32%|▎| 62/196 [00:00<00:00, 1024.21it/s, Materializing param=t
#
# Loading weights:  32%|▎| 62/196 [00:00<00:00, 1020.98it/s, Materializing param=t
#
# Loading weights:  32%|▎| 63/196 [00:00<00:00, 1031.36it/s, Materializing param=t
#
# Loading weights:  32%|▎| 63/196 [00:00<00:00, 1027.30it/s, Materializing param=t
#
# Loading weights:  33%|▎| 64/196 [00:00<00:00, 1033.36it/s, Materializing param=t
#
# Loading weights:  33%|▎| 64/196 [00:00<00:00, 1030.13it/s, Materializing param=t
#
# Loading weights:  33%|▎| 65/196 [00:00<00:00, 1039.13it/s, Materializing param=t
#
# Loading weights:  33%|▎| 65/196 [00:00<00:00, 1035.81it/s, Materializing param=t
#
# Loading weights:  34%|▎| 66/196 [00:00<00:00, 1046.08it/s, Materializing param=t
#
# Loading weights:  34%|▎| 66/196 [00:00<00:00, 1040.84it/s, Materializing param=t
#
# Loading weights:  34%|▎| 67/196 [00:00<00:00, 1049.98it/s, Materializing param=t
#
# Loading weights:  34%|▎| 67/196 [00:00<00:00, 1046.81it/s, Materializing param=t
#
# Loading weights:  35%|▎| 68/196 [00:00<00:00, 1056.79it/s, Materializing param=t
#
# Loading weights:  35%|▎| 68/196 [00:00<00:00, 1053.56it/s, Materializing param=t
#
# Loading weights:  35%|▎| 69/196 [00:00<00:00, 1062.35it/s, Materializing param=t
#
# Loading weights:  35%|▎| 69/196 [00:00<00:00, 1059.19it/s, Materializing param=t
#
# Loading weights:  36%|▎| 70/196 [00:00<00:00, 1068.79it/s, Materializing param=t
#
# Loading weights:  36%|▎| 70/196 [00:00<00:00, 1065.63it/s, Materializing param=t
#
# Loading weights:  36%|▎| 71/196 [00:00<00:00, 1074.32it/s, Materializing param=t
#
# Loading weights:  36%|▎| 71/196 [00:00<00:00, 1070.86it/s, Materializing param=t
#
# Loading weights:  37%|▎| 72/196 [00:00<00:00, 1080.46it/s, Materializing param=t
#
# Loading weights:  37%|▎| 72/196 [00:00<00:00, 1077.36it/s, Materializing param=t
#
# Loading weights:  37%|▎| 73/196 [00:00<00:00, 1085.54it/s, Materializing param=t
#
# Loading weights:  37%|▎| 73/196 [00:00<00:00, 1082.42it/s, Materializing param=t
#
# Loading weights:  38%|▍| 74/196 [00:00<00:00, 1091.90it/s, Materializing param=t
#
# Loading weights:  38%|▍| 74/196 [00:00<00:00, 1088.85it/s, Materializing param=t
#
# Loading weights:  38%|▍| 75/196 [00:00<00:00, 1096.75it/s, Materializing param=t
#
# Loading weights:  38%|▍| 75/196 [00:00<00:00, 1093.56it/s, Materializing param=t
#
# Loading weights:  39%|▍| 76/196 [00:00<00:00, 1102.87it/s, Materializing param=t
#
# Loading weights:  39%|▍| 76/196 [00:00<00:00, 1099.86it/s, Materializing param=t
#
# Loading weights:  39%|▍| 77/196 [00:00<00:00, 1107.42it/s, Materializing param=t
#
# Loading weights:  39%|▍| 77/196 [00:00<00:00, 1104.23it/s, Materializing param=t
#
# Loading weights:  40%|▍| 78/196 [00:00<00:00, 1110.68it/s, Materializing param=t
#
# Loading weights:  40%|▍| 78/196 [00:00<00:00, 1106.78it/s, Materializing param=t
#
# Loading weights:  40%|▍| 79/196 [00:00<00:00, 1115.12it/s, Materializing param=t
#
# Loading weights:  40%|▍| 79/196 [00:00<00:00, 1112.17it/s, Materializing param=t
#
# Loading weights:  41%|▍| 80/196 [00:00<00:00, 1121.54it/s, Materializing param=t
#
# Loading weights:  41%|▍| 80/196 [00:00<00:00, 1118.68it/s, Materializing param=t
#
# Loading weights:  41%|▍| 81/196 [00:00<00:00, 1127.04it/s, Materializing param=t
#
# Loading weights:  41%|▍| 81/196 [00:00<00:00, 1124.15it/s, Materializing param=t
#
# Loading weights:  42%|▍| 82/196 [00:00<00:00, 1133.13it/s, Materializing param=t
#
# Loading weights:  42%|▍| 82/196 [00:00<00:00, 1130.27it/s, Materializing param=t
#
# Loading weights:  42%|▍| 83/196 [00:00<00:00, 1139.13it/s, Materializing param=t
#
# Loading weights:  42%|▍| 83/196 [00:00<00:00, 1136.41it/s, Materializing param=t
#
# Loading weights:  43%|▍| 84/196 [00:00<00:00, 1145.60it/s, Materializing param=t
#
# Loading weights:  43%|▍| 84/196 [00:00<00:00, 1143.02it/s, Materializing param=t
#
# Loading weights:  43%|▍| 85/196 [00:00<00:00, 1152.74it/s, Materializing param=t
#
# Loading weights:  43%|▍| 85/196 [00:00<00:00, 1149.48it/s, Materializing param=t
#
# Loading weights:  44%|▍| 86/196 [00:00<00:00, 1158.00it/s, Materializing param=t
#
# Loading weights:  44%|▍| 86/196 [00:00<00:00, 1155.37it/s, Materializing param=t
#
# Loading weights:  44%|▍| 87/196 [00:00<00:00, 1164.85it/s, Materializing param=t
#
# Loading weights:  44%|▍| 87/196 [00:00<00:00, 1162.28it/s, Materializing param=t
#
# Loading weights:  45%|▍| 88/196 [00:00<00:00, 1171.00it/s, Materializing param=t
#
# Loading weights:  45%|▍| 88/196 [00:00<00:00, 1168.03it/s, Materializing param=t
#
# Loading weights:  45%|▍| 89/196 [00:00<00:00, 1177.13it/s, Materializing param=t
#
# Loading weights:  45%|▍| 89/196 [00:00<00:00, 1174.61it/s, Materializing param=t
#
# Loading weights:  46%|▍| 90/196 [00:00<00:00, 1183.92it/s, Materializing param=t
#
# Loading weights:  46%|▍| 90/196 [00:00<00:00, 1181.21it/s, Materializing param=t
#
# Loading weights:  46%|▍| 91/196 [00:00<00:00, 1189.09it/s, Materializing param=t
#
# Loading weights:  46%|▍| 91/196 [00:00<00:00, 1186.43it/s, Materializing param=t
#
# Loading weights:  47%|▍| 92/196 [00:00<00:00, 1195.44it/s, Materializing param=t
#
# Loading weights:  47%|▍| 92/196 [00:00<00:00, 1192.85it/s, Materializing param=t
#
# Loading weights:  47%|▍| 93/196 [00:00<00:00, 1201.34it/s, Materializing param=t
#
# Loading weights:  47%|▍| 93/196 [00:00<00:00, 1198.31it/s, Materializing param=t
#
# Loading weights:  48%|▍| 94/196 [00:00<00:00, 1207.12it/s, Materializing param=t
#
# Loading weights:  48%|▍| 94/196 [00:00<00:00, 1204.54it/s, Materializing param=t
#
# Loading weights:  48%|▍| 95/196 [00:00<00:00, 1213.06it/s, Materializing param=t
#
# Loading weights:  48%|▍| 95/196 [00:00<00:00, 1210.47it/s, Materializing param=t
#
# Loading weights:  49%|▍| 96/196 [00:00<00:00, 1218.07it/s, Materializing param=t
#
# Loading weights:  49%|▍| 96/196 [00:00<00:00, 1215.59it/s, Materializing param=t
#
# Loading weights:  49%|▍| 97/196 [00:00<00:00, 1224.38it/s, Materializing param=t
#
# Loading weights:  49%|▍| 97/196 [00:00<00:00, 1221.99it/s, Materializing param=t
#
# Loading weights:  50%|▌| 98/196 [00:00<00:00, 1230.95it/s, Materializing param=t
#
# Loading weights:  50%|▌| 98/196 [00:00<00:00, 1227.65it/s, Materializing param=t
#
# Loading weights:  51%|▌| 99/196 [00:00<00:00, 1236.21it/s, Materializing param=t
#
# Loading weights:  51%|▌| 99/196 [00:00<00:00, 1233.73it/s, Materializing param=t
#
# Loading weights:  51%|▌| 100/196 [00:00<00:00, 1242.61it/s, Materializing param=
#
# Loading weights:  51%|▌| 100/196 [00:00<00:00, 1240.29it/s, Materializing param=
#
# Loading weights:  52%|▌| 101/196 [00:00<00:00, 1248.57it/s, Materializing param=
#
# Loading weights:  52%|▌| 101/196 [00:00<00:00, 1246.02it/s, Materializing param=
#
# Loading weights:  52%|▌| 102/196 [00:00<00:00, 1254.32it/s, Materializing param=
#
# Loading weights:  52%|▌| 102/196 [00:00<00:00, 1251.98it/s, Materializing param=
#
# Loading weights:  53%|▌| 103/196 [00:00<00:00, 1260.92it/s, Materializing param=
#
# Loading weights:  53%|▌| 103/196 [00:00<00:00, 1258.75it/s, Materializing param=
#
# Loading weights:  53%|▌| 104/196 [00:00<00:00, 1266.93it/s, Materializing param=
#
# Loading weights:  53%|▌| 104/196 [00:00<00:00, 1264.40it/s, Materializing param=
#
# Loading weights:  54%|▌| 105/196 [00:00<00:00, 1272.93it/s, Materializing param=
#
# Loading weights:  54%|▌| 105/196 [00:00<00:00, 1270.76it/s, Materializing param=
#
# Loading weights:  54%|▌| 106/196 [00:00<00:00, 1279.52it/s, Materializing param=
#
# Loading weights:  54%|▌| 106/196 [00:00<00:00, 1277.40it/s, Materializing param=
#
# Loading weights:  55%|▌| 107/196 [00:00<00:00, 1285.19it/s, Materializing param=
#
# Loading weights:  55%|▌| 107/196 [00:00<00:00, 1282.85it/s, Materializing param=
#
# Loading weights:  55%|▌| 108/196 [00:00<00:00, 1291.43it/s, Materializing param=
#
# Loading weights:  55%|▌| 108/196 [00:00<00:00, 1289.17it/s, Materializing param=
#
# Loading weights:  56%|▌| 109/196 [00:00<00:00, 1296.51it/s, Materializing param=
#
# Loading weights:  56%|▌| 109/196 [00:00<00:00, 1293.60it/s, Materializing param=
#
# Loading weights:  56%|▌| 110/196 [00:00<00:00, 1301.39it/s, Materializing param=
#
# Loading weights:  56%|▌| 110/196 [00:00<00:00, 1299.12it/s, Materializing param=
#
# Loading weights:  57%|▌| 111/196 [00:00<00:00, 1307.35it/s, Materializing param=
#
# Loading weights:  57%|▌| 111/196 [00:00<00:00, 1304.25it/s, Materializing param=
#
# Loading weights:  57%|▌| 112/196 [00:00<00:00, 1311.94it/s, Materializing param=
#
# Loading weights:  57%|▌| 112/196 [00:00<00:00, 1309.08it/s, Materializing param=
#
# Loading weights:  58%|▌| 113/196 [00:00<00:00, 1317.17it/s, Materializing param=
#
# Loading weights:  58%|▌| 113/196 [00:00<00:00, 1314.97it/s, Materializing param=
#
# Loading weights:  58%|▌| 114/196 [00:00<00:00, 1322.58it/s, Materializing param=
#
# Loading weights:  58%|▌| 114/196 [00:00<00:00, 1319.32it/s, Materializing param=
#
# Loading weights:  59%|▌| 115/196 [00:00<00:00, 1326.10it/s, Materializing param=
#
# Loading weights:  59%|▌| 115/196 [00:00<00:00, 1323.26it/s, Materializing param=
#
# Loading weights:  59%|▌| 116/196 [00:00<00:00, 1329.95it/s, Materializing param=
#
# Loading weights:  59%|▌| 116/196 [00:00<00:00, 1327.74it/s, Materializing param=
#
# Loading weights:  60%|▌| 117/196 [00:00<00:00, 1335.96it/s, Materializing param=
#
# Loading weights:  60%|▌| 117/196 [00:00<00:00, 1333.96it/s, Materializing param=
#
# Loading weights:  60%|▌| 118/196 [00:00<00:00, 1342.30it/s, Materializing param=
#
# Loading weights:  60%|▌| 118/196 [00:00<00:00, 1340.33it/s, Materializing param=
#
# Loading weights:  61%|▌| 119/196 [00:00<00:00, 1347.93it/s, Materializing param=
#
# Loading weights:  61%|▌| 119/196 [00:00<00:00, 1345.77it/s, Materializing param=
#
# Loading weights:  61%|▌| 120/196 [00:00<00:00, 1353.87it/s, Materializing param=
#
# Loading weights:  61%|▌| 120/196 [00:00<00:00, 1351.86it/s, Materializing param=
#
# Loading weights:  62%|▌| 121/196 [00:00<00:00, 1359.97it/s, Materializing param=
#
# Loading weights:  62%|▌| 121/196 [00:00<00:00, 1357.98it/s, Materializing param=
#
# Loading weights:  62%|▌| 122/196 [00:00<00:00, 1365.82it/s, Materializing param=
#
# Loading weights:  62%|▌| 122/196 [00:00<00:00, 1362.99it/s, Materializing param=
#
# Loading weights:  63%|▋| 123/196 [00:00<00:00, 1370.85it/s, Materializing param=
#
# Loading weights:  63%|▋| 123/196 [00:00<00:00, 1368.81it/s, Materializing param=
#
# Loading weights:  63%|▋| 124/196 [00:00<00:00, 1376.83it/s, Materializing param=
#
# Loading weights:  63%|▋| 124/196 [00:00<00:00, 1374.54it/s, Materializing param=
#
# Loading weights:  64%|▋| 125/196 [00:00<00:00, 1382.45it/s, Materializing param=
#
# Loading weights:  64%|▋| 125/196 [00:00<00:00, 1379.40it/s, Materializing param=
#
# Loading weights:  64%|▋| 126/196 [00:00<00:00, 1386.84it/s, Materializing param=
#
# Loading weights:  64%|▋| 126/196 [00:00<00:00, 1384.77it/s, Materializing param=
#
# Loading weights:  65%|▋| 127/196 [00:00<00:00, 1392.36it/s, Materializing param=
#
# Loading weights:  65%|▋| 127/196 [00:00<00:00, 1390.31it/s, Materializing param=
#
# Loading weights:  65%|▋| 128/196 [00:00<00:00, 1398.26it/s, Materializing param=
#
# Loading weights:  65%|▋| 128/196 [00:00<00:00, 1395.64it/s, Materializing param=
#
# Loading weights:  66%|▋| 129/196 [00:00<00:00, 1403.32it/s, Materializing param=
#
# Loading weights:  66%|▋| 129/196 [00:00<00:00, 1401.39it/s, Materializing param=
#
# Loading weights:  66%|▋| 130/196 [00:00<00:00, 1409.08it/s, Materializing param=
#
# Loading weights:  66%|▋| 130/196 [00:00<00:00, 1407.13it/s, Materializing param=
#
# Loading weights:  67%|▋| 131/196 [00:00<00:00, 1415.01it/s, Materializing param=
#
# Loading weights:  67%|▋| 131/196 [00:00<00:00, 1413.12it/s, Materializing param=
#
# Loading weights:  67%|▋| 132/196 [00:00<00:00, 1420.09it/s, Materializing param=
#
# Loading weights:  67%|▋| 132/196 [00:00<00:00, 1418.15it/s, Materializing param=
#
# Loading weights:  68%|▋| 133/196 [00:00<00:00, 1425.78it/s, Materializing param=
#
# Loading weights:  68%|▋| 133/196 [00:00<00:00, 1423.87it/s, Materializing param=
#
# Loading weights:  68%|▋| 134/196 [00:00<00:00, 1431.81it/s, Materializing param=
#
# Loading weights:  68%|▋| 134/196 [00:00<00:00, 1430.00it/s, Materializing param=
#
# Loading weights:  69%|▋| 135/196 [00:00<00:00, 1437.90it/s, Materializing param=
#
# Loading weights:  69%|▋| 135/196 [00:00<00:00, 1435.52it/s, Materializing param=
#
# Loading weights:  69%|▋| 136/196 [00:00<00:00, 1443.05it/s, Materializing param=
#
# Loading weights:  69%|▋| 136/196 [00:00<00:00, 1441.27it/s, Materializing param=
#
# Loading weights:  70%|▋| 137/196 [00:00<00:00, 1449.14it/s, Materializing param=
#
# Loading weights:  70%|▋| 137/196 [00:00<00:00, 1447.39it/s, Materializing param=
#
# Loading weights:  70%|▋| 138/196 [00:00<00:00, 1455.12it/s, Materializing param=
#
# Loading weights:  70%|▋| 138/196 [00:00<00:00, 1453.24it/s, Materializing param=
#
# Loading weights:  71%|▋| 139/196 [00:00<00:00, 1460.51it/s, Materializing param=
#
# Loading weights:  71%|▋| 139/196 [00:00<00:00, 1458.05it/s, Materializing param=
#
# Loading weights:  71%|▋| 140/196 [00:00<00:00, 1465.27it/s, Materializing param=
#
# Loading weights:  71%|▋| 140/196 [00:00<00:00, 1463.44it/s, Materializing param=
#
# Loading weights:  72%|▋| 141/196 [00:00<00:00, 1471.15it/s, Materializing param=
#
# Loading weights:  72%|▋| 141/196 [00:00<00:00, 1469.33it/s, Materializing param=
#
# Loading weights:  72%|▋| 142/196 [00:00<00:00, 1476.99it/s, Materializing param=
#
# Loading weights:  72%|▋| 142/196 [00:00<00:00, 1474.97it/s, Materializing param=
#
# Loading weights:  73%|▋| 143/196 [00:00<00:00, 1482.11it/s, Materializing param=
#
# Loading weights:  73%|▋| 143/196 [00:00<00:00, 1479.71it/s, Materializing param=
#
# Loading weights:  73%|▋| 144/196 [00:00<00:00, 1486.94it/s, Materializing param=
#
# Loading weights:  73%|▋| 144/196 [00:00<00:00, 1485.11it/s, Materializing param=
#
# Loading weights:  74%|▋| 145/196 [00:00<00:00, 1492.65it/s, Materializing param=
#
# Loading weights:  74%|▋| 145/196 [00:00<00:00, 1490.60it/s, Materializing param=
#
# Loading weights:  74%|▋| 146/196 [00:00<00:00, 1498.09it/s, Materializing param=
#
# Loading weights:  74%|▋| 146/196 [00:00<00:00, 1496.30it/s, Materializing param=
#
# Loading weights:  75%|▊| 147/196 [00:00<00:00, 1503.45it/s, Materializing param=
#
# Loading weights:  75%|▊| 147/196 [00:00<00:00, 1500.88it/s, Materializing param=
#
# Loading weights:  76%|▊| 148/196 [00:00<00:00, 1508.24it/s, Materializing param=
#
# Loading weights:  76%|▊| 148/196 [00:00<00:00, 1506.36it/s, Materializing param=
#
# Loading weights:  76%|▊| 149/196 [00:00<00:00, 1513.92it/s, Materializing param=
#
# Loading weights:  76%|▊| 149/196 [00:00<00:00, 1512.22it/s, Materializing param=
#
# Loading weights:  77%|▊| 150/196 [00:00<00:00, 1519.76it/s, Materializing param=
#
# Loading weights:  77%|▊| 150/196 [00:00<00:00, 1518.05it/s, Materializing param=
#
# Loading weights:  77%|▊| 151/196 [00:00<00:00, 1525.52it/s, Materializing param=
#
# Loading weights:  77%|▊| 151/196 [00:00<00:00, 1523.35it/s, Materializing param=
#
# Loading weights:  78%|▊| 152/196 [00:00<00:00, 1530.48it/s, Materializing param=
#
# Loading weights:  78%|▊| 152/196 [00:00<00:00, 1528.81it/s, Materializing param=
#
# Loading weights:  78%|▊| 153/196 [00:00<00:00, 1536.31it/s, Materializing param=
#
# Loading weights:  78%|▊| 153/196 [00:00<00:00, 1534.69it/s, Materializing param=
#
# Loading weights:  79%|▊| 154/196 [00:00<00:00, 1542.19it/s, Materializing param=
#
# Loading weights:  79%|▊| 154/196 [00:00<00:00, 1540.53it/s, Materializing param=
#
# Loading weights:  79%|▊| 155/196 [00:00<00:00, 1548.03it/s, Materializing param=
#
# Loading weights:  79%|▊| 155/196 [00:00<00:00, 1548.03it/s, Materializing param=
#
# Loading weights:  79%|▊| 155/196 [00:00<00:00, 1548.03it/s, Materializing param=
#
# Loading weights:  80%|▊| 156/196 [00:00<00:00, 1548.03it/s, Materializing param=
#
# Loading weights:  80%|▊| 156/196 [00:00<00:00, 1548.03it/s, Materializing param=
#
# Loading weights:  80%|▊| 157/196 [00:00<00:00, 1548.03it/s, Materializing param=
#
# Loading weights:  80%|▊| 157/196 [00:00<00:00, 1548.03it/s, Materializing param=
#
# Loading weights:  81%|▊| 158/196 [00:00<00:00, 1548.03it/s, Materializing param=
#
# Loading weights:  81%|▊| 158/196 [00:00<00:00, 1548.03it/s, Materializing param=
#
# Loading weights:  81%|▊| 159/196 [00:00<00:00, 1548.03it/s, Materializing param=
#
# Loading weights:  81%|▊| 159/196 [00:00<00:00, 1548.03it/s, Materializing param=
#
# Loading weights:  82%|▊| 160/196 [00:00<00:00, 1548.03it/s, Materializing param=
#
# Loading weights:  82%|▊| 160/196 [00:00<00:00, 1548.03it/s, Materializing param=
#
# Loading weights:  82%|▊| 161/196 [00:00<00:00, 1548.03it/s, Materializing param=
#
# Loading weights:  82%|▊| 161/196 [00:00<00:00, 1548.03it/s, Materializing param=
#
# Loading weights:  83%|▊| 162/196 [00:00<00:00, 1548.03it/s, Materializing param=
#
# Loading weights:  83%|▊| 162/196 [00:00<00:00, 1548.03it/s, Materializing param=
#
# Loading weights:  83%|▊| 163/196 [00:00<00:00, 1548.03it/s, Materializing param=
#
# Loading weights:  83%|▊| 163/196 [00:00<00:00, 1548.03it/s, Materializing param=
#
# Loading weights:  84%|▊| 164/196 [00:00<00:00, 1548.03it/s, Materializing param=
#
# Loading weights:  84%|▊| 164/196 [00:00<00:00, 1548.03it/s, Materializing param=
#
# Loading weights:  84%|▊| 165/196 [00:00<00:00, 1548.03it/s, Materializing param=
#
# Loading weights:  84%|▊| 165/196 [00:00<00:00, 1548.03it/s, Materializing param=
#
# Loading weights:  85%|▊| 166/196 [00:00<00:00, 1548.03it/s, Materializing param=
#
# Loading weights:  85%|▊| 166/196 [00:00<00:00, 1548.03it/s, Materializing param=
#
# Loading weights:  85%|▊| 167/196 [00:00<00:00, 1548.03it/s, Materializing param=
#
# Loading weights:  85%|▊| 167/196 [00:00<00:00, 1548.03it/s, Materializing param=
#
# Loading weights:  86%|▊| 168/196 [00:00<00:00, 1548.03it/s, Materializing param=
#
# Loading weights:  86%|▊| 168/196 [00:00<00:00, 1548.03it/s, Materializing param=
#
# Loading weights:  86%|▊| 169/196 [00:00<00:00, 1548.03it/s, Materializing param=
#
# Loading weights:  86%|▊| 169/196 [00:00<00:00, 1548.03it/s, Materializing param=
#
# Loading weights:  87%|▊| 170/196 [00:00<00:00, 1548.03it/s, Materializing param=
#
# Loading weights:  87%|▊| 170/196 [00:00<00:00, 1548.03it/s, Materializing param=
#
# Loading weights:  87%|▊| 171/196 [00:00<00:00, 1548.03it/s, Materializing param=
#
# Loading weights:  87%|▊| 171/196 [00:00<00:00, 1548.03it/s, Materializing param=
#
# Loading weights:  88%|▉| 172/196 [00:00<00:00, 1548.03it/s, Materializing param=
#
# Loading weights:  88%|▉| 172/196 [00:00<00:00, 1548.03it/s, Materializing param=
#
# Loading weights:  88%|▉| 173/196 [00:00<00:00, 1548.03it/s, Materializing param=
#
# Loading weights:  88%|▉| 173/196 [00:00<00:00, 1548.03it/s, Materializing param=
#
# Loading weights:  89%|▉| 174/196 [00:00<00:00, 1548.03it/s, Materializing param=
#
# Loading weights:  89%|▉| 174/196 [00:00<00:00, 1548.03it/s, Materializing param=
#
# Loading weights:  89%|▉| 175/196 [00:00<00:00, 1548.03it/s, Materializing param=
#
# Loading weights:  89%|▉| 175/196 [00:00<00:00, 1548.03it/s, Materializing param=
#
# Loading weights:  90%|▉| 176/196 [00:00<00:00, 1548.03it/s, Materializing param=
#
# Loading weights:  90%|▉| 176/196 [00:00<00:00, 1548.03it/s, Materializing param=
#
# Loading weights:  90%|▉| 177/196 [00:00<00:00, 1548.03it/s, Materializing param=
#
# Loading weights:  90%|▉| 177/196 [00:00<00:00, 1548.03it/s, Materializing param=
#
# Loading weights:  91%|▉| 178/196 [00:00<00:00, 1548.03it/s, Materializing param=
#
# Loading weights:  91%|▉| 178/196 [00:00<00:00, 1548.03it/s, Materializing param=
#
# Loading weights:  91%|▉| 179/196 [00:00<00:00, 1548.03it/s, Materializing param=
#
# Loading weights:  91%|▉| 179/196 [00:00<00:00, 1548.03it/s, Materializing param=
#
# Loading weights:  92%|▉| 180/196 [00:00<00:00, 1548.03it/s, Materializing param=
#
# Loading weights:  92%|▉| 180/196 [00:00<00:00, 1548.03it/s, Materializing param=
#
# Loading weights:  92%|▉| 181/196 [00:00<00:00, 1548.03it/s, Materializing param=
#
# Loading weights:  92%|▉| 181/196 [00:00<00:00, 1548.03it/s, Materializing param=
#
# Loading weights:  93%|▉| 182/196 [00:00<00:00, 1548.03it/s, Materializing param=
#
# Loading weights:  93%|▉| 182/196 [00:00<00:00, 1548.03it/s, Materializing param=
#
# Loading weights:  93%|▉| 183/196 [00:00<00:00, 1548.03it/s, Materializing param=
#
# Loading weights:  93%|▉| 183/196 [00:00<00:00, 1548.03it/s, Materializing param=
#
# Loading weights:  94%|▉| 184/196 [00:00<00:00, 1548.03it/s, Materializing param=
#
# Loading weights:  94%|▉| 184/196 [00:00<00:00, 1548.03it/s, Materializing param=
#
# Loading weights:  94%|▉| 185/196 [00:00<00:00, 1548.03it/s, Materializing param=
#
# Loading weights:  94%|▉| 185/196 [00:00<00:00, 1548.03it/s, Materializing param=
#
# Loading weights:  95%|▉| 186/196 [00:00<00:00, 1548.03it/s, Materializing param=
#
# Loading weights:  95%|▉| 186/196 [00:00<00:00, 1548.03it/s, Materializing param=
#
# Loading weights:  95%|▉| 187/196 [00:00<00:00, 1548.03it/s, Materializing param=
#
# Loading weights:  95%|▉| 187/196 [00:00<00:00, 1548.03it/s, Materializing param=
#
# Loading weights:  96%|▉| 188/196 [00:00<00:00, 1548.03it/s, Materializing param=
#
# Loading weights:  96%|▉| 188/196 [00:00<00:00, 1548.03it/s, Materializing param=
#
# Loading weights:  96%|▉| 189/196 [00:00<00:00, 1548.03it/s, Materializing param=
#
# Loading weights:  96%|▉| 189/196 [00:00<00:00, 1548.03it/s, Materializing param=
#
# Loading weights:  97%|▉| 190/196 [00:00<00:00, 1548.03it/s, Materializing param=
#
# Loading weights:  97%|▉| 190/196 [00:00<00:00, 1548.03it/s, Materializing param=
#
# Loading weights:  97%|▉| 191/196 [00:00<00:00, 1548.03it/s, Materializing param=
#
# Loading weights:  97%|▉| 191/196 [00:00<00:00, 1548.03it/s, Materializing param=
#
# Loading weights:  98%|▉| 192/196 [00:00<00:00, 1548.03it/s, Materializing param=
#
# Loading weights:  98%|▉| 192/196 [00:00<00:00, 1548.03it/s, Materializing param=
#
# Loading weights:  98%|▉| 193/196 [00:00<00:00, 1548.03it/s, Materializing param=
#
# Loading weights:  98%|▉| 193/196 [00:00<00:00, 1548.03it/s, Materializing param=
#
# Loading weights:  99%|▉| 194/196 [00:00<00:00, 1548.03it/s, Materializing param=
#
# Loading weights:  99%|▉| 194/196 [00:00<00:00, 1548.03it/s, Materializing param=
#
# Loading weights:  99%|▉| 195/196 [00:00<00:00, 1548.03it/s, Materializing param=
#
# Loading weights:  99%|▉| 195/196 [00:00<00:00, 1548.03it/s, Materializing param=
#
# Loading weights: 100%|█| 196/196 [00:00<00:00, 1548.03it/s, Materializing param=
#
# Loading weights: 100%|█| 196/196 [00:00<00:00, 1753.88it/s, Materializing param=
#
# Loading pipeline components...:  14%|█▊           | 1/7 [00:00<00:01,  3.83it/s]
#
# Loading weights:   0%|                                  | 0/219 [00:00<?, ?it/s]
#
# Loading weights:   0%| | 1/219 [00:00<00:00, 29330.80it/s, Materializing param=e
#
# Loading weights:   0%| | 1/219 [00:00<00:00, 7598.38it/s, Materializing param=en
#
# Loading weights:   1%| | 2/219 [00:00<00:00, 6017.65it/s, Materializing param=en
#
# Loading weights:   1%| | 2/219 [00:00<00:00, 4818.27it/s, Materializing param=en
#
# Loading weights:   1%| | 3/219 [00:00<00:00, 2567.42it/s, Materializing param=en
#
# Loading weights:   1%| | 3/219 [00:00<00:00, 2280.75it/s, Materializing param=en
#
# Loading weights:   2%| | 4/219 [00:00<00:00, 2596.29it/s, Materializing param=en
#
# Loading weights:   2%| | 4/219 [00:00<00:00, 2415.38it/s, Materializing param=en
#
# Loading weights:   2%| | 5/219 [00:00<00:00, 2687.97it/s, Materializing param=en
#
# Loading weights:   2%| | 5/219 [00:00<00:00, 2443.95it/s, Materializing param=en
#
# Loading weights:   3%| | 6/219 [00:00<00:00, 2359.66it/s, Materializing param=en
#
# Loading weights:   3%| | 6/219 [00:00<00:00, 2271.28it/s, Materializing param=en
#
# Loading weights:   3%| | 7/219 [00:00<00:00, 2387.58it/s, Materializing param=en
#
# Loading weights:   3%| | 7/219 [00:00<00:00, 2327.03it/s, Materializing param=en
#
# Loading weights:   4%| | 8/219 [00:00<00:00, 2179.43it/s, Materializing param=en
#
# Loading weights:   4%| | 8/219 [00:00<00:00, 1906.50it/s, Materializing param=en
#
# Loading weights:   4%| | 9/219 [00:00<00:02, 95.92it/s, Materializing param=enco
#
# Loading weights:   4%| | 9/219 [00:00<00:02, 95.71it/s, Materializing param=enco
#
# Loading weights:   5%| | 10/219 [00:00<00:01, 106.08it/s, Materializing param=en
#
# Loading weights:   5%| | 10/219 [00:00<00:01, 105.93it/s, Materializing param=en
#
# Loading weights:   5%| | 11/219 [00:00<00:01, 116.25it/s, Materializing param=en
#
# Loading weights:   5%| | 11/219 [00:00<00:01, 116.09it/s, Materializing param=en
#
# Loading weights:   5%| | 12/219 [00:00<00:01, 126.37it/s, Materializing param=en
#
# Loading weights:   5%| | 12/219 [00:00<00:01, 126.18it/s, Materializing param=en
#
# Loading weights:   6%| | 13/219 [00:00<00:01, 136.38it/s, Materializing param=en
#
# Loading weights:   6%| | 13/219 [00:00<00:01, 136.22it/s, Materializing param=en
#
# Loading weights:   6%| | 14/219 [00:00<00:01, 146.37it/s, Materializing param=en
#
# Loading weights:   6%| | 14/219 [00:00<00:01, 146.19it/s, Materializing param=en
#
# Loading weights:   7%| | 15/219 [00:00<00:01, 156.28it/s, Materializing param=en
#
# Loading weights:   7%| | 15/219 [00:00<00:01, 156.08it/s, Materializing param=en
#
# Loading weights:   7%| | 16/219 [00:00<00:01, 166.16it/s, Materializing param=en
#
# Loading weights:   7%| | 16/219 [00:00<00:01, 165.95it/s, Materializing param=en
#
# Loading weights:   8%| | 17/219 [00:00<00:01, 175.94it/s, Materializing param=en
#
# Loading weights:   8%| | 17/219 [00:00<00:01, 175.72it/s, Materializing param=en
#
# Loading weights:   8%| | 18/219 [00:00<00:01, 185.67it/s, Materializing param=en
#
# Loading weights:   8%| | 18/219 [00:00<00:01, 185.44it/s, Materializing param=en
#
# Loading weights:   9%| | 19/219 [00:00<00:01, 195.36it/s, Materializing param=en
#
# Loading weights:   9%| | 19/219 [00:00<00:01, 195.12it/s, Materializing param=en
#
# Loading weights:   9%| | 20/219 [00:00<00:00, 205.02it/s, Materializing param=en
#
# Loading weights:   9%| | 20/219 [00:00<00:00, 204.75it/s, Materializing param=en
#
# Loading weights:  10%| | 21/219 [00:00<00:00, 214.57it/s, Materializing param=en
#
# Loading weights:  10%| | 21/219 [00:00<00:00, 214.31it/s, Materializing param=en
#
# Loading weights:  10%| | 22/219 [00:00<00:00, 224.06it/s, Materializing param=en
#
# Loading weights:  10%| | 22/219 [00:00<00:00, 223.89it/s, Materializing param=en
#
# Loading weights:  11%| | 23/219 [00:00<00:00, 233.79it/s, Materializing param=en
#
# Loading weights:  11%| | 23/219 [00:00<00:00, 233.62it/s, Materializing param=en
#
# Loading weights:  11%| | 24/219 [00:00<00:00, 243.50it/s, Materializing param=en
#
# Loading weights:  11%| | 24/219 [00:00<00:00, 243.29it/s, Materializing param=en
#
# Loading weights:  11%| | 25/219 [00:00<00:00, 253.11it/s, Materializing param=en
#
# Loading weights:  11%| | 25/219 [00:00<00:00, 252.93it/s, Materializing param=en
#
# Loading weights:  12%| | 26/219 [00:00<00:00, 262.12it/s, Materializing param=en
#
# Loading weights:  12%| | 26/219 [00:00<00:00, 261.38it/s, Materializing param=en
#
# Loading weights:  12%| | 27/219 [00:00<00:00, 270.83it/s, Materializing param=en
#
# Loading weights:  12%| | 27/219 [00:00<00:00, 270.49it/s, Materializing param=en
#
# Loading weights:  13%|▏| 28/219 [00:00<00:01, 146.52it/s, Materializing param=en
#
# Loading weights:  13%|▏| 28/219 [00:00<00:01, 146.52it/s, Materializing param=en
#
# Loading weights:  13%|▏| 28/219 [00:00<00:01, 146.52it/s, Materializing param=en
#
# Loading weights:  13%|▏| 29/219 [00:00<00:01, 146.52it/s, Materializing param=en
#
# Loading weights:  13%|▏| 29/219 [00:00<00:01, 146.52it/s, Materializing param=en
#
# Loading weights:  14%|▏| 30/219 [00:00<00:01, 146.52it/s, Materializing param=en
#
# Loading weights:  14%|▏| 30/219 [00:00<00:01, 146.52it/s, Materializing param=en
#
# Loading weights:  14%|▏| 31/219 [00:00<00:01, 146.52it/s, Materializing param=en
#
# Loading weights:  14%|▏| 31/219 [00:00<00:01, 146.52it/s, Materializing param=en
#
# Loading weights:  15%|▏| 32/219 [00:00<00:01, 146.52it/s, Materializing param=en
#
# Loading weights:  15%|▏| 32/219 [00:00<00:01, 146.52it/s, Materializing param=en
#
# Loading weights:  15%|▏| 33/219 [00:00<00:01, 146.52it/s, Materializing param=en
#
# Loading weights:  15%|▏| 33/219 [00:00<00:01, 146.52it/s, Materializing param=en
#
# Loading weights:  16%|▏| 34/219 [00:00<00:01, 146.52it/s, Materializing param=en
#
# Loading weights:  16%|▏| 34/219 [00:00<00:01, 146.52it/s, Materializing param=en
#
# Loading weights:  16%|▏| 35/219 [00:00<00:01, 146.52it/s, Materializing param=en
#
# Loading weights:  16%|▏| 35/219 [00:00<00:01, 146.52it/s, Materializing param=en
#
# Loading weights:  16%|▏| 36/219 [00:00<00:01, 146.52it/s, Materializing param=en
#
# Loading weights:  16%|▏| 36/219 [00:00<00:01, 146.52it/s, Materializing param=en
#
# Loading weights:  17%|▏| 37/219 [00:00<00:01, 146.52it/s, Materializing param=en
#
# Loading weights:  17%|▏| 37/219 [00:00<00:01, 146.52it/s, Materializing param=en
#
# Loading weights:  17%|▏| 38/219 [00:00<00:01, 146.52it/s, Materializing param=en
#
# Loading weights:  17%|▏| 38/219 [00:00<00:01, 146.52it/s, Materializing param=en
#
# Loading weights:  18%|▏| 39/219 [00:00<00:01, 146.52it/s, Materializing param=en
#
# Loading weights:  18%|▏| 39/219 [00:00<00:01, 146.52it/s, Materializing param=en
#
# Loading weights:  18%|▏| 40/219 [00:00<00:01, 146.52it/s, Materializing param=en
#
# Loading weights:  18%|▏| 40/219 [00:00<00:01, 146.52it/s, Materializing param=en
#
# Loading weights:  19%|▏| 41/219 [00:00<00:01, 146.52it/s, Materializing param=en
#
# Loading weights:  19%|▏| 41/219 [00:00<00:01, 146.52it/s, Materializing param=en
#
# Loading weights:  19%|▏| 42/219 [00:00<00:01, 146.52it/s, Materializing param=en
#
# Loading weights:  19%|▏| 42/219 [00:00<00:01, 146.52it/s, Materializing param=en
#
# Loading weights:  20%|▏| 43/219 [00:00<00:01, 142.06it/s, Materializing param=en
#
# Loading weights:  20%|▏| 43/219 [00:00<00:01, 142.06it/s, Materializing param=en
#
# Loading weights:  20%|▏| 43/219 [00:00<00:01, 142.06it/s, Materializing param=en
#
# Loading weights:  20%|▏| 44/219 [00:00<00:01, 142.06it/s, Materializing param=en
#
# Loading weights:  20%|▏| 44/219 [00:00<00:01, 142.06it/s, Materializing param=en
#
# Loading weights:  21%|▏| 45/219 [00:00<00:01, 142.06it/s, Materializing param=en
#
# Loading weights:  21%|▏| 45/219 [00:00<00:01, 142.06it/s, Materializing param=en
#
# Loading weights:  21%|▏| 46/219 [00:00<00:01, 142.06it/s, Materializing param=en
#
# Loading weights:  21%|▏| 46/219 [00:00<00:01, 142.06it/s, Materializing param=en
#
# Loading weights:  21%|▏| 47/219 [00:00<00:01, 142.06it/s, Materializing param=en
#
# Loading weights:  21%|▏| 47/219 [00:00<00:01, 142.06it/s, Materializing param=en
#
# Loading weights:  22%|▏| 48/219 [00:00<00:01, 142.06it/s, Materializing param=en
#
# Loading weights:  22%|▏| 48/219 [00:00<00:01, 142.06it/s, Materializing param=en
#
# Loading weights:  22%|▏| 49/219 [00:00<00:01, 142.06it/s, Materializing param=en
#
# Loading weights:  22%|▏| 49/219 [00:00<00:01, 142.06it/s, Materializing param=en
#
# Loading weights:  23%|▏| 50/219 [00:00<00:01, 142.06it/s, Materializing param=en
#
# Loading weights:  23%|▏| 50/219 [00:00<00:01, 142.06it/s, Materializing param=en
#
# Loading weights:  23%|▏| 51/219 [00:00<00:01, 142.06it/s, Materializing param=en
#
# Loading weights:  23%|▏| 51/219 [00:00<00:01, 142.06it/s, Materializing param=en
#
# Loading weights:  24%|▏| 52/219 [00:00<00:01, 142.06it/s, Materializing param=en
#
# Loading weights:  24%|▏| 52/219 [00:00<00:01, 142.06it/s, Materializing param=en
#
# Loading weights:  24%|▏| 53/219 [00:00<00:01, 142.06it/s, Materializing param=en
#
# Loading weights:  24%|▏| 53/219 [00:00<00:01, 142.06it/s, Materializing param=en
#
# Loading weights:  25%|▏| 54/219 [00:00<00:01, 142.06it/s, Materializing param=en
#
# Loading weights:  25%|▏| 54/219 [00:00<00:01, 142.06it/s, Materializing param=en
#
# Loading weights:  25%|▎| 55/219 [00:00<00:01, 142.06it/s, Materializing param=en
#
# Loading weights:  25%|▎| 55/219 [00:00<00:01, 142.06it/s, Materializing param=en
#
# Loading weights:  26%|▎| 56/219 [00:00<00:01, 142.06it/s, Materializing param=en
#
# Loading weights:  26%|▎| 56/219 [00:00<00:01, 142.06it/s, Materializing param=en
#
# Loading weights:  26%|▎| 57/219 [00:00<00:01, 142.06it/s, Materializing param=en
#
# Loading weights:  26%|▎| 57/219 [00:00<00:01, 142.06it/s, Materializing param=en
#
# Loading weights:  26%|▎| 58/219 [00:00<00:01, 107.30it/s, Materializing param=en
#
# Loading weights:  26%|▎| 58/219 [00:00<00:01, 107.30it/s, Materializing param=en
#
# Loading weights:  26%|▎| 58/219 [00:00<00:01, 107.30it/s, Materializing param=en
#
# Loading weights:  27%|▎| 59/219 [00:00<00:01, 107.30it/s, Materializing param=en
#
# Loading weights:  27%|▎| 59/219 [00:00<00:01, 107.30it/s, Materializing param=en
#
# Loading weights:  27%|▎| 60/219 [00:00<00:01, 107.30it/s, Materializing param=en
#
# Loading weights:  27%|▎| 60/219 [00:00<00:01, 107.30it/s, Materializing param=en
#
# Loading weights:  28%|▎| 61/219 [00:00<00:01, 107.30it/s, Materializing param=en
#
# Loading weights:  28%|▎| 61/219 [00:00<00:01, 107.30it/s, Materializing param=en
#
# Loading weights:  28%|▎| 62/219 [00:00<00:01, 107.30it/s, Materializing param=en
#
# Loading weights:  28%|▎| 62/219 [00:00<00:01, 107.30it/s, Materializing param=en
#
# Loading weights:  29%|▎| 63/219 [00:00<00:01, 107.30it/s, Materializing param=en
#
# Loading weights:  29%|▎| 63/219 [00:00<00:01, 107.30it/s, Materializing param=en
#
# Loading weights:  29%|▎| 64/219 [00:00<00:01, 107.30it/s, Materializing param=en
#
# Loading weights:  29%|▎| 64/219 [00:00<00:01, 107.30it/s, Materializing param=en
#
# Loading weights:  30%|▎| 65/219 [00:00<00:01, 107.30it/s, Materializing param=en
#
# Loading weights:  30%|▎| 65/219 [00:00<00:01, 107.30it/s, Materializing param=en
#
# Loading weights:  30%|▎| 66/219 [00:00<00:01, 107.30it/s, Materializing param=en
#
# Loading weights:  30%|▎| 66/219 [00:00<00:01, 107.30it/s, Materializing param=en
#
# Loading weights:  31%|▎| 67/219 [00:00<00:01, 107.30it/s, Materializing param=en
#
# Loading weights:  31%|▎| 67/219 [00:00<00:01, 107.30it/s, Materializing param=en
#
# Loading weights:  31%|▎| 68/219 [00:00<00:01, 107.30it/s, Materializing param=en
#
# Loading weights:  31%|▎| 68/219 [00:00<00:01, 107.30it/s, Materializing param=en
#
# Loading weights:  32%|▎| 69/219 [00:00<00:01, 107.30it/s, Materializing param=en
#
# Loading weights:  32%|▎| 69/219 [00:00<00:01, 107.30it/s, Materializing param=en
#
# Loading weights:  32%|▎| 70/219 [00:00<00:01, 107.30it/s, Materializing param=en
#
# Loading weights:  32%|▎| 70/219 [00:00<00:01, 107.30it/s, Materializing param=en
#
# Loading weights:  32%|▎| 71/219 [00:00<00:01, 113.58it/s, Materializing param=en
#
# Loading weights:  32%|▎| 71/219 [00:00<00:01, 113.58it/s, Materializing param=en
#
# Loading weights:  32%|▎| 71/219 [00:00<00:01, 113.58it/s, Materializing param=en
#
# Loading weights:  33%|▎| 72/219 [00:00<00:01, 113.58it/s, Materializing param=en
#
# Loading weights:  33%|▎| 72/219 [00:00<00:01, 113.58it/s, Materializing param=en
#
# Loading weights:  33%|▎| 73/219 [00:00<00:01, 113.58it/s, Materializing param=en
#
# Loading weights:  33%|▎| 73/219 [00:00<00:01, 113.58it/s, Materializing param=en
#
# Loading weights:  34%|▎| 74/219 [00:00<00:01, 113.58it/s, Materializing param=en
#
# Loading weights:  34%|▎| 74/219 [00:00<00:01, 113.58it/s, Materializing param=en
#
# Loading weights:  34%|▎| 75/219 [00:00<00:01, 113.58it/s, Materializing param=en
#
# Loading weights:  34%|▎| 75/219 [00:00<00:01, 113.58it/s, Materializing param=en
#
# Loading weights:  35%|▎| 76/219 [00:00<00:01, 113.58it/s, Materializing param=en
#
# Loading weights:  35%|▎| 76/219 [00:00<00:01, 113.58it/s, Materializing param=en
#
# Loading weights:  35%|▎| 77/219 [00:00<00:01, 113.58it/s, Materializing param=en
#
# Loading weights:  35%|▎| 77/219 [00:00<00:01, 113.58it/s, Materializing param=en
#
# Loading weights:  36%|▎| 78/219 [00:00<00:01, 113.58it/s, Materializing param=en
#
# Loading weights:  36%|▎| 78/219 [00:00<00:01, 113.58it/s, Materializing param=en
#
# Loading weights:  36%|▎| 79/219 [00:00<00:01, 113.58it/s, Materializing param=en
#
# Loading weights:  36%|▎| 79/219 [00:00<00:01, 113.58it/s, Materializing param=en
#
# Loading weights:  37%|▎| 80/219 [00:00<00:01, 113.58it/s, Materializing param=en
#
# Loading weights:  37%|▎| 80/219 [00:00<00:01, 113.58it/s, Materializing param=en
#
# Loading weights:  37%|▎| 81/219 [00:00<00:01, 113.58it/s, Materializing param=en
#
# Loading weights:  37%|▎| 81/219 [00:00<00:01, 113.58it/s, Materializing param=en
#
# Loading weights:  37%|▎| 82/219 [00:00<00:01, 113.58it/s, Materializing param=en
#
# Loading weights:  37%|▎| 82/219 [00:00<00:01, 113.58it/s, Materializing param=en
#
# Loading weights:  38%|▍| 83/219 [00:00<00:01, 113.58it/s, Materializing param=en
#
# Loading weights:  38%|▍| 83/219 [00:00<00:01, 113.58it/s, Materializing param=en
#
# Loading weights:  38%|▍| 84/219 [00:00<00:01, 113.58it/s, Materializing param=en
#
# ...
#
# Loading weights:  65%|▋| 142/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  65%|▋| 143/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  65%|▋| 143/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  66%|▋| 144/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  66%|▋| 144/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  66%|▋| 145/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  66%|▋| 145/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  67%|▋| 146/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  67%|▋| 146/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  67%|▋| 147/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  67%|▋| 147/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  68%|▋| 148/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  68%|▋| 148/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  68%|▋| 149/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  68%|▋| 149/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  68%|▋| 150/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  68%|▋| 150/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  69%|▋| 151/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  69%|▋| 151/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  69%|▋| 152/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  69%|▋| 152/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  70%|▋| 153/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  70%|▋| 153/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  70%|▋| 154/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  70%|▋| 154/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  71%|▋| 155/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  71%|▋| 155/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  71%|▋| 156/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  71%|▋| 156/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  72%|▋| 157/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  72%|▋| 157/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  72%|▋| 158/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  72%|▋| 158/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  73%|▋| 159/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  73%|▋| 159/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  73%|▋| 160/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  73%|▋| 160/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  74%|▋| 161/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  74%|▋| 161/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  74%|▋| 162/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  74%|▋| 162/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  74%|▋| 163/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  74%|▋| 163/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  75%|▋| 164/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  75%|▋| 164/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  75%|▊| 165/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  75%|▊| 165/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  76%|▊| 166/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  76%|▊| 166/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  76%|▊| 167/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  76%|▊| 167/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  77%|▊| 168/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  77%|▊| 168/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  77%|▊| 169/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  77%|▊| 169/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  78%|▊| 170/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  78%|▊| 170/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  78%|▊| 171/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  78%|▊| 171/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  79%|▊| 172/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  79%|▊| 172/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  79%|▊| 173/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  79%|▊| 173/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  79%|▊| 174/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  79%|▊| 174/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  80%|▊| 175/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  80%|▊| 175/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  80%|▊| 176/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  80%|▊| 176/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  81%|▊| 177/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  81%|▊| 177/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  81%|▊| 178/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  81%|▊| 178/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  82%|▊| 179/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  82%|▊| 179/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  82%|▊| 180/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  82%|▊| 180/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  83%|▊| 181/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  83%|▊| 181/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  83%|▊| 182/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  83%|▊| 182/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  84%|▊| 183/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  84%|▊| 183/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  84%|▊| 184/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  84%|▊| 184/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  84%|▊| 185/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  84%|▊| 185/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  85%|▊| 186/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  85%|▊| 186/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  85%|▊| 187/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  85%|▊| 187/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  86%|▊| 188/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  86%|▊| 188/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  86%|▊| 189/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  86%|▊| 189/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  87%|▊| 190/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  87%|▊| 190/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  87%|▊| 191/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  87%|▊| 191/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  88%|▉| 192/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  88%|▉| 192/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  88%|▉| 193/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  88%|▉| 193/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  89%|▉| 194/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  89%|▉| 194/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  89%|▉| 195/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  89%|▉| 195/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  89%|▉| 196/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  89%|▉| 196/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  90%|▉| 197/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  90%|▉| 197/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  90%|▉| 198/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  90%|▉| 198/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  91%|▉| 199/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  91%|▉| 199/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  91%|▉| 200/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  91%|▉| 200/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  92%|▉| 201/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  92%|▉| 201/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  92%|▉| 202/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  92%|▉| 202/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  93%|▉| 203/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  93%|▉| 203/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  93%|▉| 204/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  93%|▉| 204/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  94%|▉| 205/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  94%|▉| 205/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  94%|▉| 206/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  94%|▉| 206/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  95%|▉| 207/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  95%|▉| 207/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  95%|▉| 208/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  95%|▉| 208/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  95%|▉| 209/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  95%|▉| 209/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  96%|▉| 210/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  96%|▉| 210/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  96%|▉| 211/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  96%|▉| 211/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  97%|▉| 212/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  97%|▉| 212/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  97%|▉| 213/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  97%|▉| 213/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  98%|▉| 214/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  98%|▉| 214/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  98%|▉| 215/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  98%|▉| 215/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  99%|▉| 216/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  99%|▉| 216/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  99%|▉| 217/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights:  99%|▉| 217/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights: 100%|▉| 218/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights: 100%|▉| 218/219 [00:01<00:00, 130.39it/s, Materializing param=e
#
# Loading weights: 100%|█| 219/219 [00:01<00:00, 130.39it/s, Materializing param=s
#
# Loading weights: 100%|█| 219/219 [00:01<00:00, 209.40it/s, Materializing param=s
#
# Loading pipeline components...:  29%|███▋         | 2/7 [00:01<00:04,  1.17it/s]
#
# Loading checkpoint shards:   0%|                          | 0/3 [00:00<?, ?it/s]
#
# Loading checkpoint shards: 100%|██████████████████| 3/3 [00:00<00:00, 13.92it/s]
#
# Loading pipeline components...:  43%|█████▌       | 3/7 [00:01<00:02,  1.56it/s]
# Loading pipeline components...:  71%|█████████▎   | 5/7 [00:02<00:00,  2.86it/s]
# Loading pipeline components...: 100%|█████████████| 7/7 [00:02<00:00,  2.97it/s]
# Download complete: 100%|███████████████████| 33.7G/33.7G [01:06<00:00, 1.03GB/s]a street sign in city, filmfotos, film grain, reversal film photography
#
#   0%|                                                    | 0/30 [00:00<?, ?it/s]
#   3%|█▍                                          | 1/30 [00:01<00:35,  1.22s/it]
#   7%|██▉                                         | 2/30 [00:02<00:27,  1.01it/s]
#  10%|████▍                                       | 3/30 [00:03<00:29,  1.08s/it]
#  13%|█████▊                                      | 4/30 [00:04<00:29,  1.13s/it]
#  17%|███████▎                                    | 5/30 [00:05<00:28,  1.15s/it]
#  20%|████████▊                                   | 6/30 [00:06<00:27,  1.16s/it]
#  23%|██████████▎                                 | 7/30 [00:08<00:26,  1.17s/it]
#  27%|███████████▋                                | 8/30 [00:09<00:25,  1.18s/it]
#  30%|█████████████▏                              | 9/30 [00:10<00:24,  1.18s/it]
#  33%|██████████████▎                            | 10/30 [00:11<00:23,  1.18s/it]
#  37%|███████████████▊                           | 11/30 [00:12<00:22,  1.18s/it]
#  40%|█████████████████▏                         | 12/30 [00:13<00:21,  1.18s/it]
#  43%|██████████████████▋                        | 13/30 [00:15<00:20,  1.18s/it]
#  47%|████████████████████                       | 14/30 [00:16<00:18,  1.19s/it]
#  50%|█████████████████████▌                     | 15/30 [00:17<00:17,  1.19s/it]
#  53%|██████████████████████▉                    | 16/30 [00:18<00:16,  1.19s/it]
#  57%|████████████████████████▎                  | 17/30 [00:19<00:15,  1.19s/it]
#  60%|█████████████████████████▊                 | 18/30 [00:21<00:14,  1.19s/it]
#  63%|███████████████████████████▏               | 19/30 [00:22<00:13,  1.19s/it]
#  67%|████████████████████████████▋              | 20/30 [00:23<00:11,  1.19s/it]
#  70%|██████████████████████████████             | 21/30 [00:24<00:10,  1.19s/it]
#  73%|███████████████████████████████▌           | 22/30 [00:25<00:09,  1.20s/it]
#  77%|████████████████████████████████▉          | 23/30 [00:27<00:08,  1.20s/it]
#  80%|██████████████████████████████████▍        | 24/30 [00:28<00:07,  1.20s/it]
#  83%|███████████████████████████████████▊       | 25/30 [00:29<00:05,  1.20s/it]
#  87%|█████████████████████████████████████▎     | 26/30 [00:30<00:04,  1.20s/it]
#  90%|██████████████████████████████████████▋    | 27/30 [00:31<00:03,  1.20s/it]
#  93%|████████████████████████████████████████▏  | 28/30 [00:33<00:02,  1.20s/it]
#  97%|█████████████████████████████████████████▌ | 29/30 [00:34<00:01,  1.20s/it]
# 100%|███████████████████████████████████████████| 30/30 [00:35<00:00,  1.18s/it]
# Download complete: 100%|████████████████████| 33.7G/33.7G [01:45<00:00, 320MB/s]

# %%
import torch
from controlnet_flux import FluxControlNetModel
from pipeline_flux_controlnet import FluxControlNetPipeline

from PIL import Image, ImageDraw, ImageFont
import numpy as np
import cv2
import re
import os

def contains_chinese(text):
    if re.search(r'[\u4e00-\u9fff]', text):
        return True
    return False

def canny(img):
    low_threshold = 50
    high_threshold = 100
    img = cv2.Canny(img, low_threshold, high_threshold)
    img = img[:, :, None]
    img = 255 - np.concatenate([img, img, img], axis=2)
    return img

# %%
# !nvidia-smi
# Out:
# Thu Feb  5 08:33:02 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 570.195.03             Driver Version: 570.195.03     CUDA Version: 12.8     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A40                     On  |   00000000:52:00.0 Off |                    0 |
# |  0%   31C    P8             34W /  300W |       3MiB /  46068MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
base_model = "black-forest-labs/FLUX.1-dev"
controlnet_model = "Shakker-Labs/RepText"

controlnet = FluxControlNetModel.from_pretrained(controlnet_model, torch_dtype=torch.bfloat16)
pipe = FluxControlNetPipeline.from_pretrained(
    base_model, controlnet=controlnet, torch_dtype=torch.bfloat16
).to("cuda")

## set resolution
width, height = 1024, 1024
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_validators.py:202: UserWarning: The `local_dir_use_symlinks` argument is deprecated and ignored in `hf_hub_download`. Downloading to a local directory does not use symlinks anymore.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/diffusers/models/embeddings.py:2617: FutureWarning: `FluxPosEmbed` is deprecated and will be removed in version 1.0.0. Importing and using `FluxPosEmbed` from `diffusers.models.embeddings` is deprecated. Please import it from `diffusers.models.transformers.transformer_flux`.
#   deprecate("FluxPosEmbed", "1.0.0", deprecation_message)
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/196 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/219 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]

# %%
def predict(text="hi!!",prompt='a street sign in city'):
    ## set text content, position, color
    text_list = [text]
    text_position_list = [(370, 200)]
    text_color_list = [(255, 255, 255)]
    
    # text_list = ["Shakker Labs"]
    # text_position_list = [(270, 300)]
    # text_color_list = [(255, 255, 255)]
    
    # text_list = ["Lovart AI", "Always Day 1"]
    # text_position_list = [(470, 300), (470, 400)]
    # text_color_list = [(255, 255, 255), (255, 255, 255)]
    
    # text_list = ["以往不谏", "来者可追"]
    # text_position_list = [(200, 200), (200, 300)]
    # text_color_list = [(255, 255, 255), (255, 255, 255)]
    
    # text_list = ["Shakker Labs", "RepText"]
    # text_position_list = [(200, 200), (200, 300)]
    # text_color_list = [(255, 255, 255), (255, 255, 255)]
    
    ## set controlnet conditions
    control_image_list = [] # canny list
    control_position_list = [] # position list
    control_mask_list = [] # regional mask list
    control_glyph_all = np.zeros([height, width, 3], dtype=np.uint8) # all glyphs
    
    ## handle each line of text
    for text, text_position, text_color in zip(text_list, text_position_list, text_color_list):
    
        ### glyph image, render text to black background
        control_image_glyph = Image.new("RGB", (width, height), (0, 0, 0))
        draw = ImageDraw.Draw(control_image_glyph)
        draw.text(text_position, text, font=font, fill=text_color)
        
        ### get bbox
        bbox = draw.textbbox(text_position, text, font=font)
        
        ### position condition
        control_position = np.zeros([height, width], dtype=np.uint8)
        control_position[bbox[1]:bbox[3], bbox[0]:bbox[2]] = 255
        control_position = Image.fromarray(control_position.astype(np.uint8))
        control_position_list.append(control_position)
        
        ### regional mask
        control_mask_np = np.zeros([height, width], dtype=np.uint8)
        control_mask_np[bbox[1]-5:bbox[3]+5, bbox[0]-5:bbox[2]+5] = 255
        control_mask = Image.fromarray(control_mask_np.astype(np.uint8))
        control_mask_list.append(control_mask)
        
        ### accumulate glyph
        control_glyph = np.array(control_image_glyph)
        control_glyph_all += control_glyph
        
        ### canny condition
        control_image = canny(cv2.cvtColor(np.array(control_image_glyph), cv2.COLOR_RGB2BGR))
        control_image = Image.fromarray(cv2.cvtColor(control_image, cv2.COLOR_BGR2RGB))
        control_image_list.append(control_image)
    
    control_glyph_all = Image.fromarray(control_glyph_all.astype(np.uint8))
    control_glyph_all = control_glyph_all.convert("RGB")
    # control_glyph_all.save("./results/control_glyph.jpg")
    
    # it is recommended to use words such 'sign', 'billboard', 'banner' in your prompt
    # for Englith text, it helps if you add the text to the prompt
    
    for text in text_list:
    if not contains_chinese(text):
        prompt += f", '{text}'"
    prompt += ", filmfotos, film grain, reversal film photography" # optional
    print(prompt)
    
    generator = torch.Generator(device="cuda").manual_seed(42)
    
    image = pipe(
    prompt,
    control_image=control_image_list, # canny
    control_position=control_position_list, # position
    control_mask=control_mask_list, # regional mask
    control_glyph=control_glyph_all, # as init latent, optional, set to None if not used
    controlnet_conditioning_scale=1.0,
    controlnet_conditioning_step=30,
    width=width,
    height=height,
    num_inference_steps=30,
    guidance_scale=3.5,
    generator=generator,
    ).images[0]
    
    if not os.path.exists("./results"):
    os.makedirs("./results")
    image.save(f"./results/result.jpg")
# Out:
#   Cell In[14], line 69
#     if not contains_chinese(text):
#     ^
# IndentationError: expected an indented block after 'for' statement on line 68
